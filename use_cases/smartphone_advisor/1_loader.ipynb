# %% [markdown]
# # Smartphones and Watches advisor
# In this serie of notebooks we will:
# - **Load text from a Youtube video playlist**
# - Split loaded text into appropriate chunks
# - Create a vector store to load chunk embeddings
# - Create a Question Answering chatbot:
#
#     - with different prompts techniques
#     - with different similarity measures
#     - with or without chat memory
#
# !['Data Connection'](../../images/les_numeriques_youtube/data_connection.png)
#
# # How to create a Text Loader from a Youtube video playlist ?
#
# From a playlist link
# - Get all the urls in the playlist
# - Apply the speech to Text Whisper module
# - Create a data loader

# %%
# Imports 
# Youtube
import time
from pytube import YouTube, Playlist

# Env var
import os 
import sys
from dotenv import load_dotenv, find_dotenv

# Langchain
import openai
from langchain.document_loaders.generic import GenericLoader
from langchain.document_loaders.parsers import OpenAIWhisperParser
from langchain.document_loaders.blob_loaders.youtube_audio import YoutubeAudioLoader

# Save loader
from utils import save_docs_to_jsonl

# %%
# Les numériques - Smartphones et montées connectées
PLAYLIST_LINK = "https://www.youtube.com/playlist?list=PLhqibKns24ALiMaHTfEedcon0LzEAxu7q"
PATH_NAME_LOADER = './loaded_docs.jsonl'

# %%
# Video URLs from playlist
video_links = Playlist(PLAYLIST_LINK).video_urls
print(f"There are {len(video_links)} videos")
# Out:
# There are 302 videos

# %% [markdown]
# <div align="left">
#       <a href="https://www.youtube.com/watch?v=PJ7qsF6LFSU">
#          <img src="https://img.youtube.com/vi/PJ7qsF6LFSU/0.jpg" style="width:100%;">
#       </a>
# </div>

# %%
# Env variable
sys.path.append('../..')
_ = load_dotenv(find_dotenv())
openai.api_key = os.environ['OPENAI_API_KEY']

# %%
# Load Text from videos
save_dir="docs/youtube/"

loader = GenericLoader(
    YoutubeAudioLoader([video_links[:30]], save_dir),
    OpenAIWhisperParser()
)
docs = loader.load()
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MYX6xLYWJoU
# [youtube] MYX6xLYWJoU: Downloading webpage
# [youtube] MYX6xLYWJoU: Downloading ios player API JSON
# [youtube] MYX6xLYWJoU: Downloading android player API JSON
# [youtube] MYX6xLYWJoU: Downloading m3u8 information
# [info] MYX6xLYWJoU: Downloading 1 format(s): 140
# [download] docs/youtube//Stalké par un AirTag ？.m4a has already been downloaded
# [download] 100% of  947.70KiB
# [ExtractAudio] Not converting audio docs/youtube//Stalké par un AirTag ？.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=THSjWVl80Qc
# [youtube] THSjWVl80Qc: Downloading webpage
# [youtube] THSjWVl80Qc: Downloading ios player API JSON
# [youtube] THSjWVl80Qc: Downloading android player API JSON
# [youtube] THSjWVl80Qc: Downloading m3u8 information
# [info] THSjWVl80Qc: Downloading 1 format(s): 140
# [download] docs/youtube//La nouvelle puce du Galaxy S23.m4a has already been downloaded
# [download] 100% of    5.82MiB
# [ExtractAudio] Not converting audio docs/youtube//La nouvelle puce du Galaxy S23.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=sAh9eUjgt-I
# [youtube] sAh9eUjgt-I: Downloading webpage
# [youtube] sAh9eUjgt-I: Downloading ios player API JSON
# [youtube] sAh9eUjgt-I: Downloading android player API JSON
# [youtube] sAh9eUjgt-I: Downloading m3u8 information
# [info] sAh9eUjgt-I: Downloading 1 format(s): 140
# [download] docs/youtube//📱 Le Magic Vs d'Honor arrive pour faire de l'ombre aux Samsung Galaxy Z Fold 4..m4a has already been downloaded
# [download] 100% of  779.38KiB
# [ExtractAudio] Not converting audio docs/youtube//📱 Le Magic Vs d'Honor arrive pour faire de l'ombre aux Samsung Galaxy Z Fold 4..m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Anqv4jaykB4
# [youtube] Anqv4jaykB4: Downloading webpage
# [youtube] Anqv4jaykB4: Downloading ios player API JSON
# [youtube] Anqv4jaykB4: Downloading android player API JSON
# [youtube] Anqv4jaykB4: Downloading m3u8 information
# [info] Anqv4jaykB4: Downloading 1 format(s): 140
# [download] docs/youtube//Google Pixel 7 ⧸ 7 Pro ： formule peaufinée, inflation maîtrisée.m4a has already been downloaded
# [download] 100% of    8.60MiB
# [ExtractAudio] Not converting audio docs/youtube//Google Pixel 7 ⧸ 7 Pro ： formule peaufinée, inflation maîtrisée.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=frb21wRl7os
# [youtube] frb21wRl7os: Downloading webpage
# [youtube] frb21wRl7os: Downloading ios player API JSON
# [youtube] frb21wRl7os: Downloading android player API JSON
# [youtube] frb21wRl7os: Downloading m3u8 information
# [info] frb21wRl7os: Downloading 1 format(s): 140
# [download] docs/youtube//Made by Google '22 ： Pixels 7, Pixel Watch... le récap des produits !.m4a has already been downloaded
# [download] 100% of    4.46MiB
# [ExtractAudio] Not converting audio docs/youtube//Made by Google '22 ： Pixels 7, Pixel Watch... le récap des produits !.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=a-_JCSwomQQ
# [youtube] a-_JCSwomQQ: Downloading webpage
# [youtube] a-_JCSwomQQ: Downloading ios player API JSON
# [youtube] a-_JCSwomQQ: Downloading android player API JSON
# [youtube] a-_JCSwomQQ: Downloading m3u8 information
# [info] a-_JCSwomQQ: Downloading 1 format(s): 140
# [download] docs/youtube//📱 200 Mpx pour convaincre. #xiaomi.m4a has already been downloaded
# [download] 100% of  917.29KiB
# [ExtractAudio] Not converting audio docs/youtube//📱 200 Mpx pour convaincre. #xiaomi.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PJ7qsF6LFSU
# [youtube] PJ7qsF6LFSU: Downloading webpage
# [youtube] PJ7qsF6LFSU: Downloading ios player API JSON
# [youtube] PJ7qsF6LFSU: Downloading android player API JSON
# [youtube] PJ7qsF6LFSU: Downloading m3u8 information
# [info] PJ7qsF6LFSU: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//[TEST] iPhone 14 Pro et Pro Max ： la maturité avant les changements ？.m4a
# [download] 100% of    6.75MiB in 00:00:00 at 19.85MiB/s
# [FixupM4a] Correcting container of "docs/youtube//[TEST] iPhone 14 Pro et Pro Max ： la maturité avant les changements ？.m4a"
# [ExtractAudio] Not converting audio docs/youtube//[TEST] iPhone 14 Pro et Pro Max ： la maturité avant les changements ？.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=S265JHGo-5g
# [youtube] S265JHGo-5g: Downloading webpage
# [youtube] S265JHGo-5g: Downloading ios player API JSON
# [youtube] S265JHGo-5g: Downloading android player API JSON
# [youtube] S265JHGo-5g: Downloading m3u8 information
# [info] S265JHGo-5g: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Apple Watch Series 8 ： une Ultra pour attaquer Garmin.m4a
# [download] 100% of    6.56MiB in 00:00:00 at 20.01MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Apple Watch Series 8 ： une Ultra pour attaquer Garmin.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Apple Watch Series 8 ： une Ultra pour attaquer Garmin.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ubxlnbu8Wc4
# [youtube] ubxlnbu8Wc4: Downloading webpage
# [youtube] ubxlnbu8Wc4: Downloading ios player API JSON
# [youtube] ubxlnbu8Wc4: Downloading android player API JSON
# [youtube] ubxlnbu8Wc4: Downloading m3u8 information
# [info] ubxlnbu8Wc4: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//iPhone 14 ： la gamme Pro gâtée, l'autre oubliée.m4a
# [download] 100% of    7.66MiB in 00:00:00 at 18.46MiB/s
# [FixupM4a] Correcting container of "docs/youtube//iPhone 14 ： la gamme Pro gâtée, l'autre oubliée.m4a"
# [ExtractAudio] Not converting audio docs/youtube//iPhone 14 ： la gamme Pro gâtée, l'autre oubliée.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=N8NfWnFmU_g
# [youtube] N8NfWnFmU_g: Downloading webpage
# [youtube] N8NfWnFmU_g: Downloading ios player API JSON
# [youtube] N8NfWnFmU_g: Downloading android player API JSON
# [youtube] N8NfWnFmU_g: Downloading m3u8 information
# [info] N8NfWnFmU_g: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Test Samsung Galaxy Watch 5 ： l'autonomie sous Wear OS passe par la Pro.m4a
# [download] 100% of   15.50MiB in 00:00:00 at 19.70MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Test Samsung Galaxy Watch 5 ： l'autonomie sous Wear OS passe par la Pro.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Test Samsung Galaxy Watch 5 ： l'autonomie sous Wear OS passe par la Pro.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_lQ0F7__pKA
# [youtube] _lQ0F7__pKA: Downloading webpage
# [youtube] _lQ0F7__pKA: Downloading ios player API JSON
# [youtube] _lQ0F7__pKA: Downloading android player API JSON
# [youtube] _lQ0F7__pKA: Downloading m3u8 information
# [info] _lQ0F7__pKA: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Test Phone (1) de Nothing ： pas besoin d'être un iPhone pour briller !.m4a
# [download] 100% of    6.91MiB in 00:00:00 at 19.41MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Test Phone (1) de Nothing ： pas besoin d'être un iPhone pour briller !.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Test Phone (1) de Nothing ： pas besoin d'être un iPhone pour briller !.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9o-2Z0VSQSI
# [youtube] 9o-2Z0VSQSI: Downloading webpage
# [youtube] 9o-2Z0VSQSI: Downloading ios player API JSON
# [youtube] 9o-2Z0VSQSI: Downloading android player API JSON
# [youtube] 9o-2Z0VSQSI: Downloading m3u8 information
# [info] 9o-2Z0VSQSI: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Test du Google Pixel 6a ： le meilleur plan à moins de 500 € ？.m4a
# [download] 100% of    7.49MiB in 00:00:00 at 19.46MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Test du Google Pixel 6a ： le meilleur plan à moins de 500 € ？.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Test du Google Pixel 6a ： le meilleur plan à moins de 500 € ？.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mnPJILodOos
# [youtube] mnPJILodOos: Downloading webpage
# [youtube] mnPJILodOos: Downloading ios player API JSON
# [youtube] mnPJILodOos: Downloading android player API JSON
# [youtube] mnPJILodOos: Downloading m3u8 information
# [info] mnPJILodOos: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Vous n'aurez pas droit aux Xiaomi 12S, 12S Pro et 12S Ultra !.m4a
# [download] 100% of    5.70MiB in 00:00:00 at 10.28MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Vous n'aurez pas droit aux Xiaomi 12S, 12S Pro et 12S Ultra !.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Vous n'aurez pas droit aux Xiaomi 12S, 12S Pro et 12S Ultra !.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dIv_zi0FI6g
# [youtube] dIv_zi0FI6g: Downloading webpage
# [youtube] dIv_zi0FI6g: Downloading ios player API JSON
# [youtube] dIv_zi0FI6g: Downloading android player API JSON
# [youtube] dIv_zi0FI6g: Downloading m3u8 information
# [info] dIv_zi0FI6g: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Test Huawei Watch GT 3 Pro ： Toujours aussi sportive ？.m4a
# [download] 100% of    7.69MiB in 00:00:00 at 17.29MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Test Huawei Watch GT 3 Pro ： Toujours aussi sportive ？.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Test Huawei Watch GT 3 Pro ： Toujours aussi sportive ？.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0RiuIpmBCig
# [youtube] 0RiuIpmBCig: Downloading webpage
# [youtube] 0RiuIpmBCig: Downloading ios player API JSON
# [youtube] 0RiuIpmBCig: Downloading android player API JSON
# [youtube] 0RiuIpmBCig: Downloading m3u8 information
# [info] 0RiuIpmBCig: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Gamme Xiaomi Redmi Note 11 ： quel est le meilleur smartphone ？.m4a
# [download] 100% of    8.51MiB in 00:00:00 at 18.81MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Gamme Xiaomi Redmi Note 11 ： quel est le meilleur smartphone ？.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Gamme Xiaomi Redmi Note 11 ： quel est le meilleur smartphone ？.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=aXjgyMaZmro
# [youtube] aXjgyMaZmro: Downloading webpage
# [youtube] aXjgyMaZmro: Downloading ios player API JSON
# [youtube] aXjgyMaZmro: Downloading android player API JSON
# [youtube] aXjgyMaZmro: Downloading m3u8 information
# [info] aXjgyMaZmro: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Google I⧸O 2022 ： toutes les annonces produits !.m4a
# [download] 100% of    4.46MiB in 00:00:00 at 18.88MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Google I⧸O 2022 ： toutes les annonces produits !.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Google I⧸O 2022 ： toutes les annonces produits !.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=eVWLsjmNdg4
# [youtube] eVWLsjmNdg4: Downloading webpage
# [youtube] eVWLsjmNdg4: Downloading ios player API JSON
# [youtube] eVWLsjmNdg4: Downloading android player API JSON
# [youtube] eVWLsjmNdg4: Downloading m3u8 information
# [info] eVWLsjmNdg4: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//iPhone SE 2022 ： la puissance et c'est tout ？.m4a
# [download] 100% of   10.29MiB in 00:00:00 at 18.78MiB/s
# [FixupM4a] Correcting container of "docs/youtube//iPhone SE 2022 ： la puissance et c'est tout ？.m4a"
# [ExtractAudio] Not converting audio docs/youtube//iPhone SE 2022 ： la puissance et c'est tout ？.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FzmpQ07QbWU
# [youtube] FzmpQ07QbWU: Downloading webpage
# [youtube] FzmpQ07QbWU: Downloading ios player API JSON
# [youtube] FzmpQ07QbWU: Downloading android player API JSON
# [youtube] FzmpQ07QbWU: Downloading m3u8 information
# [info] FzmpQ07QbWU: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Test Samsung Galaxy A53 ： la photo, plus que le jeu.m4a
# [download] 100% of    9.90MiB in 00:00:00 at 23.61MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Test Samsung Galaxy A53 ： la photo, plus que le jeu.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Test Samsung Galaxy A53 ： la photo, plus que le jeu.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1DEcJ4jjUHo
# [youtube] 1DEcJ4jjUHo: Downloading webpage
# [youtube] 1DEcJ4jjUHo: Downloading ios player API JSON
# [youtube] 1DEcJ4jjUHo: Downloading android player API JSON
# [youtube] 1DEcJ4jjUHo: Downloading m3u8 information
# [info] 1DEcJ4jjUHo: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Test Samsung Galaxy S22 et S22 + ： solides, mais pas sans compromis.m4a
# [download] 100% of   15.18MiB in 00:00:00 at 19.83MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Test Samsung Galaxy S22 et S22 + ： solides, mais pas sans compromis.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Test Samsung Galaxy S22 et S22 + ： solides, mais pas sans compromis.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2Lxa6_jcfVM
# [youtube] 2Lxa6_jcfVM: Downloading webpage
# [youtube] 2Lxa6_jcfVM: Downloading ios player API JSON
# [youtube] 2Lxa6_jcfVM: Downloading android player API JSON
# [youtube] 2Lxa6_jcfVM: Downloading m3u8 information
# [info] 2Lxa6_jcfVM: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Test Xiaomi 11 T PRO ： Une recharge rapide et furieuse.m4a
# [download] 100% of   12.01MiB in 00:00:01 at 11.11MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Test Xiaomi 11 T PRO ： Une recharge rapide et furieuse.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Test Xiaomi 11 T PRO ： Une recharge rapide et furieuse.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=HETEwXESyx8
# [youtube] HETEwXESyx8: Downloading webpage
# [youtube] HETEwXESyx8: Downloading ios player API JSON
# [youtube] HETEwXESyx8: Downloading android player API JSON
# [youtube] HETEwXESyx8: Downloading m3u8 information
# [info] HETEwXESyx8: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Test iPhone 13 ： notre verdict sur toute la gamme.m4a
# [download] 100% of   17.45MiB in 00:00:00 at 23.19MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Test iPhone 13 ： notre verdict sur toute la gamme.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Test iPhone 13 ： notre verdict sur toute la gamme.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Lxr0dtcwhBw
# [youtube] Lxr0dtcwhBw: Downloading webpage
# [youtube] Lxr0dtcwhBw: Downloading ios player API JSON
# [youtube] Lxr0dtcwhBw: Downloading android player API JSON
# [youtube] Lxr0dtcwhBw: Downloading m3u8 information
# [info] Lxr0dtcwhBw: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//iPhone 13 ： On déballe tous les derniers iPhone d'Apple.m4a
# [download] 100% of   12.77MiB in 00:00:00 at 22.46MiB/s
# [FixupM4a] Correcting container of "docs/youtube//iPhone 13 ： On déballe tous les derniers iPhone d'Apple.m4a"
# [ExtractAudio] Not converting audio docs/youtube//iPhone 13 ： On déballe tous les derniers iPhone d'Apple.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XjDCao2n2Jg
# [youtube] XjDCao2n2Jg: Downloading webpage
# [youtube] XjDCao2n2Jg: Downloading ios player API JSON
# [youtube] XjDCao2n2Jg: Downloading android player API JSON
# [youtube] XjDCao2n2Jg: Downloading m3u8 information
# [info] XjDCao2n2Jg: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Les annonces de Xiaomi ： notre récap.m4a
# [download] 100% of   30.49MiB in 00:00:01 at 18.78MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Les annonces de Xiaomi ： notre récap.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Les annonces de Xiaomi ： notre récap.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=waJ7AHRFILg
# [youtube] waJ7AHRFILg: Downloading webpage
# [youtube] waJ7AHRFILg: Downloading ios player API JSON
# [youtube] waJ7AHRFILg: Downloading android player API JSON
# [youtube] waJ7AHRFILg: Downloading m3u8 information
# [info] waJ7AHRFILg: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//iPhone 13, Watch Serie 7, iPad Mini... Récap des annonces Apple.m4a
# [download] 100% of    8.23MiB in 00:00:00 at 24.81MiB/s
# [FixupM4a] Correcting container of "docs/youtube//iPhone 13, Watch Serie 7, iPad Mini... Récap des annonces Apple.m4a"
# [ExtractAudio] Not converting audio docs/youtube//iPhone 13, Watch Serie 7, iPad Mini... Récap des annonces Apple.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GWQfEZePJvM
# [youtube] GWQfEZePJvM: Downloading webpage
# [youtube] GWQfEZePJvM: Downloading ios player API JSON
# [youtube] GWQfEZePJvM: Downloading android player API JSON
# [youtube] GWQfEZePJvM: Downloading m3u8 information
# [info] GWQfEZePJvM: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Test du Galaxy A22 ： une autonomie de l'espace.m4a
# [download] 100% of    7.32MiB in 00:00:00 at 22.54MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Test du Galaxy A22 ： une autonomie de l'espace.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Test du Galaxy A22 ： une autonomie de l'espace.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fb6VnOdeX48
# [youtube] fb6VnOdeX48: Downloading webpage
# [youtube] fb6VnOdeX48: Downloading ios player API JSON
# [youtube] fb6VnOdeX48: Downloading android player API JSON
# [youtube] fb6VnOdeX48: Downloading m3u8 information
# [info] fb6VnOdeX48: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//iPhone 13 ： dates, rumeurs, ragots....m4a
# [download] 100% of    6.79MiB in 00:00:00 at 24.54MiB/s
# [FixupM4a] Correcting container of "docs/youtube//iPhone 13 ： dates, rumeurs, ragots....m4a"
# [ExtractAudio] Not converting audio docs/youtube//iPhone 13 ： dates, rumeurs, ragots....m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Lsq-e7fzVeg
# [youtube] Lsq-e7fzVeg: Downloading webpage
# [youtube] Lsq-e7fzVeg: Downloading ios player API JSON
# [youtube] Lsq-e7fzVeg: Downloading android player API JSON
# [youtube] Lsq-e7fzVeg: Downloading m3u8 information
# [info] Lsq-e7fzVeg: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Test Z Fold 3 ： Pas de fausse Note chez Samsung ？.m4a
# [download] 100% of    9.51MiB in 00:00:00 at 25.87MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Test Z Fold 3 ： Pas de fausse Note chez Samsung ？.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Test Z Fold 3 ： Pas de fausse Note chez Samsung ？.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Rbi31NTyTIM
# [youtube] Rbi31NTyTIM: Downloading webpage
# [youtube] Rbi31NTyTIM: Downloading ios player API JSON
# [youtube] Rbi31NTyTIM: Downloading android player API JSON
# [youtube] Rbi31NTyTIM: Downloading m3u8 information
# [info] Rbi31NTyTIM: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Test Samsung Galaxy Z Flip 3 ： rien ne l'effraie, sauf....m4a
# [download] 100% of   13.44MiB in 00:00:00 at 20.41MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Test Samsung Galaxy Z Flip 3 ： rien ne l'effraie, sauf....m4a"
# [ExtractAudio] Not converting audio docs/youtube//Test Samsung Galaxy Z Flip 3 ： rien ne l'effraie, sauf....m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=DBvHFrebD9M
# [youtube] DBvHFrebD9M: Downloading webpage
# [youtube] DBvHFrebD9M: Downloading ios player API JSON
# [youtube] DBvHFrebD9M: Downloading android player API JSON
# [youtube] DBvHFrebD9M: Downloading m3u8 information
# [info] DBvHFrebD9M: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Galaxy Fold 3 et Flip 3 ： Pas 1 mais 2 Messi(es) chez Samsung ？.m4a
# [download] 100% of    8.25MiB in 00:00:00 at 16.07MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Galaxy Fold 3 et Flip 3 ： Pas 1 mais 2 Messi(es) chez Samsung ？.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Galaxy Fold 3 et Flip 3 ： Pas 1 mais 2 Messi(es) chez Samsung ？.m4a; file is already in target format m4a
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zh9iYCYsUM4
# [youtube] zh9iYCYsUM4: Downloading webpage
# [youtube] zh9iYCYsUM4: Downloading ios player API JSON
# [youtube] zh9iYCYsUM4: Downloading android player API JSON
# [youtube] zh9iYCYsUM4: Downloading m3u8 information
# [info] zh9iYCYsUM4: Downloading 1 format(s): 140
# [download] Destination: docs/youtube//Pixel 6 officiels ： Google veut vous faire oublier Apple et Samsung, mais à quel prix ？.m4a
# [download] 100% of    3.57MiB in 00:00:00 at 15.91MiB/s
# [FixupM4a] Correcting container of "docs/youtube//Pixel 6 officiels ： Google veut vous faire oublier Apple et Samsung, mais à quel prix ？.m4a"
# [ExtractAudio] Not converting audio docs/youtube//Pixel 6 officiels ： Google veut vous faire oublier Apple et Samsung, mais à quel prix ？.m4a; file is already in target format m4a
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 2!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!
# Transcribing part 1!

# %%
docs[5]
# Out:
# Document(page_content="Bonjour à tous et bienvenue sur Les Numériques. Aujourd'hui, on va parler des Pixel 7 et Pixel 7 Pro, les nouveaux smartphones de Google. On commence par le premier, vendu 649 euros, le modèle standard reprend les mêmes codes de design que les Pixel, à savoir un hilo photo proéminent qui occupe toute la largeur du smartphone et met en avant les capteurs. Google a opté pour une finition en métal, contrairement au vert du modèle précédent. C'est une esthétique qui avait fait débat l'an dernier, même si l'ensemble paraît ici un peu moins agressif, notamment grâce aux bords arrondis. A la rédaction, nous, on aime plutôt bien, notamment dans les nouvelles couleurs, comme le vert citron. Alors, il faut savoir que le Pixel 7 a effectué une petite cure de minceur puisqu'il pèse 197 grammes. Ce n'est pas forcément léger, mais c'est 10 de moins que le Pixel 6. Le dos conserve toujours cette finition en vert qui accroche d'ailleurs un peu trop les traces de doigts. Et l'ensemble est toujours certifié IP68, il est donc étanche, ce qui est quand même rassurant. Au niveau de l'écran, rien de forcément nouveau non plus. Il embarque une dalle à molette, cette fois-ci de 6,3 pouces contre 6,4 pouces pour le Pixel 6. Elle affiche en Full HD+, et elle profite d'un taux de rafraîchissement de 90 Hertz. Il faut savoir que les deux mobiles, la version standard et la version Pro, sont protégés par du Gorilla Glass Victus, donc rassurant également. La dalle en question est bien lumineuse puisqu'on a calculé justement un pic lumineux à 1157 candelas. C'est très bon, c'est-à-dire que vous pouvez l'utiliser même en plein soleil à l'extérieur. Pour ce qui est de la calibration, eh bien, on vous conseille un passage sur le mode couleur naturelle. Pour mieux en profiter, vous pouvez voir toutes les spécificités de cette dalle sur notre test sur les numériques. Au niveau des performances, eh bien, on attendait Google au tournant. Et en vérité, on n'est pas vraiment déçus puisque la nouvelle puce Tensor G2, qui est gravée en 5 nanomètres, montre de très belles capacités en multitâche et en jeu. Il sera donc parfaitement possible de s'adonner au titre du Play Store dans de très bonnes conditions. Attention toutefois, car comme l'année dernière, eh bien, on note que cette puce a tendance à chauffer rapidement, on sent une chauffe importante sur des jeux très gourmands, notamment sur le téléphone. Donc, on vous conseille quand même d'espacer les sessions de jeu pour ne pas trop entamer la batterie. Et cette batterie, parlons-en, elle aussi, elle a minci, puisque le smartphone embarque un accumulateur de 4355 mAh contre 4614 mAh auparavant. Et malgré cette baisse significative, eh bien, Google promettait une meilleure gestion de la consommation et donc une autonomie un peu plus conséquente. Alors, on a testé ça également sur notre protocole de test Vizor, le smartphone a réussi à tenir 16h43, un bon score qui lui permet d'être utilisé toute la journée sans encombre. C'est tout de même moins que le Pixel 6 qui avait tenu 16h53, qui n'était pas non plus mauvais dans l'exercice. Google a donc effectivement optimisé cet aspect, mais le choix d'une batterie plus compacte, eh bien, se ressent et lui confère une autonomie plus ou moins similaire. En revanche, et c'est un peu dommage, la firme de Mountain View ne s'est toujours pas sérieusement penchée sur la question de la recharge rapide. Il nous a fallu 1h44 pour le recharger complètement avec un chargeur compatible à 30 watts. Le chargeur n'est d'ailleurs pas fourni dans la boîte. Alors, vous n'êtes pas sans savoir que Google présente ses smartphones avant tout comme des photophones. Et sur ce sujet, le Pixel 7 ne nous a pas déçu, on retrouve toujours un module principal de 50 mégapixels, couplé à un module ultra grand-angle de 12 mégapixels. C'est une configuration qui est donc similaire à celle que l'on retrouvait sur le Pixel 6, mais elle est censée bénéficier des avancées de la puce Tensor ...

# %%
save_docs_to_jsonl(docs, PATH_NAME_LOADER)
